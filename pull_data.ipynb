# %%
from data_getter import DataGetter

# %%
dg = DataGetter("ETH-USDT", "3min")
candles = dg.get_mass_candles(500000, 1)[::-1].reset_index(drop=True)
# Out:
#               FETCHING params: ETH-USDT,
#               3min,
#               start: 1716957326,
#               end: 1717227326
#
# Received Dataframe:  {'first_timestamp': 1717227180, 'last_timestamp': 1716957360, 'gaps': False, 'count': 1500}
#
#               FETCHING params: ETH-USDT,
#               3min,
#               start: 1717047180,
#               end: 1717227180
#
# Received Dataframe:  {'first_timestamp': 1717227000, 'last_timestamp': 1717047180, 'gaps': False, 'count': 1000}
#
#               FETCHING params: ETH-USDT,
#               3min,
#               start: 1716867180,
#               end: 1717047180
#
# Received Dataframe:  {'first_timestamp': 1717047000, 'last_timestamp': 1716867180, 'gaps': False, 'count': 1000}
#
#               FETCHING params: ETH-USDT,
#               3min,
#               start: 1716687180,
#               end: 1716867180
#
# ...

# %%
display(candles)
# Out:
#          timestamp     open    close     high      low      volume  \
# 0       1717227000  3784.23  3781.35  3784.23  3781.28   89.353048
# 1       1717226820  3784.20  3784.23  3784.24  3783.12   34.760910
# 2       1717226640  3785.55  3784.45  3785.61  3783.34   35.693782
# 3       1717226460  3783.65  3785.54  3786.00  3783.64   46.547672
# 4       1717226280  3786.44  3784.03  3786.44  3784.00   37.330966
# ...            ...      ...      ...      ...      ...         ...
# 499995  1627227900  2127.94  2139.58  2140.90  2127.37  328.233236
# 499996  1627227720  2125.54  2127.42  2129.70  2123.56  118.720951
# 499997  1627227540  2126.67  2125.56  2128.16  2124.23  103.789036
# 499998  1627227360  2125.92  2126.43  2126.43  2120.81   41.091840
# 499999  1627227180  2120.15  2125.91  2126.73  2120.15   83.910224
#
#                amount
# 0       337946.564562
# 1       131509.960952
# 2       135086.705517
# 3       176172.233746
# 4       141307.194617
# ...
