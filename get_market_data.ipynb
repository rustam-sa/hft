# %%
from data_service import DataService
symbols = ["ETH-USDT", "BTC-USDT"]
span = 500000

# %%
for symbol in symbols:
    ds = DataService(symbol)
    ds.save_market_data(span)
# Out:
#               FETCHING params: ETH-USDT,
#               3min,
#               start: 1717646139,
#               end: 1717916139
#
# Received Dataframe:  {'first_timestamp': 1717916040, 'last_timestamp': 1717646220, 'gaps': False, 'count': 1500}
#
#               FETCHING params: ETH-USDT,
#               3min,
#               start: 1717736040,
#               end: 1717916040
#
# Received Dataframe:  {'first_timestamp': 1717915860, 'last_timestamp': 1717736040, 'gaps': False, 'count': 1000}
#
#               FETCHING params: ETH-USDT,
#               3min,
#               start: 1717556040,
#               end: 1717736040
#
# Received Dataframe:  {'first_timestamp': 1717735860, 'last_timestamp': 1717556040, 'gaps': False, 'count': 1000}
#
#               FETCHING params: ETH-USDT,
#               3min,
#               start: 1717376040,
#               end: 1717556040
#
# ...
