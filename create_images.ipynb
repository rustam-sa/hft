# %%
from image_maker import process_and_plot_data

# %%
process_and_plot_data("image_design_save_test", fractions=[0.8, 0.1, 0.1], output_dir='image_design_save_test')
# Out:
# dataframe_get_gap
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 process_and_plot_data("image_design_save_test", fractions=[0.8, 0.1, 0.1], output_dir='image_design_save_test')
#
# File e:\coding_projects\hft\image_maker.py:129, in process_and_plot_data(collection_name, fractions, output_dir)
#     123     plot = plotter.create_minimal_candlestick_plot(
#     124         sample['data'], 'ETH-USDT', 'BTC-USDT',
#     125         y_range1=(range_min_eth, range_max_eth),
#     126         y_range2=(range_min_btc, range_max_btc)
#     127     )
#     128     labels.append(sample['label'])
# --> 129     plotter.save_plot(plot, new_output_dir, sample['timestamp'])
#     130 labels = pd.Series(labels)
#     131 labels.to_csv(new_output_dir +"/labels.csv")
#
# File e:\coding_projects\hft\plotter.py:143, in save_plot(plot, output_dir, sample_name)
# ...
